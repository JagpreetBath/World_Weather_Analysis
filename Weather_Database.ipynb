# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date,})
        
#"Current Description": city_weather_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | dhidhdhoo
# Processing Record 5 of Set 1 | hit
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | mogadishu
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | villa maria
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | hualmay
# Processing Record 16 of Set 1 | umm kaddadah
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | kuching
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | duarte
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | port lincoln
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | poum
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | caravelas
# Processing Record 38 of Set 1 | eregli
# Processing Record 39 of Set 1 | mocajuba
# Processing Record 40 of Set 1 | beausejour
# Processing Record 41 of Set 1 | havoysund
# Processing Record 42 of Set 1 | tulun
# Processing Record 43 of Set 1 | naze
# Processing Record 44 of Set 1 | jumla
# Processing Record 45 of Set 1 | saint-georges
# Processing Record 46 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 1 | vanavara
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | ranong
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | tecalitlan
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | srednekolymsk
# Processing Record 6 of Set 2 | maloy
# Processing Record 7 of Set 2 | broken hill
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | luanda
# Processing Record 10 of Set 2 | tautira
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | marawi
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | la rioja
# Processing Record 17 of Set 2 | itoman
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | ulaangom
# Processing Record 21 of Set 2 | the valley
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | aswan
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | abha
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | acari
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | qianan
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | harper
# Processing Record 38 of Set 2 | kourou
# Processing Record 39 of Set 2 | port augusta
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | bathsheba
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | ust-maya
# Processing Record 45 of Set 2 | vitim
# Processing Record 46 of Set 2 | carbondale
# Processing Record 47 of Set 2 | mayo
# Processing Record 48 of Set 2 | broome
# Processing Record 49 of Set 2 | guarapari
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | cooma
# Processing Record 2 of Set 3 | oranjestad
# Processing Record 3 of Set 3 | grand gaube
# Processing Record 4 of Set 3 | havelock
# Processing Record 5 of Set 3 | bolgar
# Processing Record 6 of Set 3 | constitucion
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | bhunya
# Processing Record 9 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 3 | ostrovnoy
# Processing Record 11 of Set 3 | pangnirtung
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | emerald
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | kimbe
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | torit
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | utete
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | rocha
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | shelburne
# Processing Record 24 of Set 3 | coahuayana
# Processing Record 25 of Set 3 | wenling
# Processing Record 26 of Set 3 | gulf gate estates
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | rajgurunagar
# Processing Record 29 of Set 3 | kotka
# Processing Record 30 of Set 3 | vostok
# Processing Record 31 of Set 3 | manono
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | ohangaron
# Processing Record 34 of Set 3 | korem
# Processing Record 35 of Set 3 | west bay
# Processing Record 36 of Set 3 | ostersund
# Processing Record 37 of Set 3 | boa vista
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | oistins
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | moron
# Processing Record 42 of Set 3 | byron bay
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | praia da vitoria
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | prince rupert
# Processing Record 50 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | dakar
# Processing Record 3 of Set 4 | impfondo
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | izberbash
# Processing Record 6 of Set 4 | rockport
# Processing Record 7 of Set 4 | tessalit
# Processing Record 8 of Set 4 | lao cai
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | avera
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | tankhoy
# Processing Record 13 of Set 4 | bereda
# Processing Record 14 of Set 4 | eenhana
# Processing Record 15 of Set 4 | vila franca do campo
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | yenisehir
# Processing Record 18 of Set 4 | necochea
# Processing Record 19 of Set 4 | port macquarie
# Processing Record 20 of Set 4 | artyom
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | wairoa
# Processing Record 25 of Set 4 | paamiut
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | ahwa
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | truth or consequences
# Processing Record 30 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 4 | newport
# Processing Record 32 of Set 4 | oriximina
# Processing Record 33 of Set 4 | kirakira
# Processing Record 34 of Set 4 | marsa matruh
# Processing Record 35 of Set 4 | basoko
# Processing Record 36 of Set 4 | nelson bay
# Processing Record 37 of Set 4 | iracoubo
# Processing Record 38 of Set 4 | ambunti
# Processing Record 39 of Set 4 | igarka
# Processing Record 40 of Set 4 | lata
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | esperance
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | mwinilunga
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | boatlaname
# City not found. Skipping...
# Processing Record 47 of Set 4 | bosaso
# Processing Record 48 of Set 4 | naron
# Processing Record 49 of Set 4 | doha
# Processing Record 50 of Set 4 | luderitz
# Processing Record 1 of Set 5 | hobyo
# Processing Record 2 of Set 5 | troitsko-pechorsk
# Processing Record 3 of Set 5 | westport
# Processing Record 4 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 7 of Set 5 | canmore
# Processing Record 8 of Set 5 | erenhot
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | green river
# Processing Record 11 of Set 5 | castro
# Processing Record 12 of Set 5 | cherdyn
# Processing Record 13 of Set 5 | thompson
# Processing Record 14 of Set 5 | senanga
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | yulara
# Processing Record 18 of Set 5 | torbay
# Processing Record 19 of Set 5 | rorvik
# Processing Record 20 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | boshnyakovo
# Processing Record 24 of Set 5 | zaysan
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | rakke
# Processing Record 27 of Set 5 | waitati
# Processing Record 28 of Set 5 | huilong
# Processing Record 29 of Set 5 | malanje
# Processing Record 30 of Set 5 | bhag
# Processing Record 31 of Set 5 | vertou
# Processing Record 32 of Set 5 | ivanivka
# Processing Record 33 of Set 5 | bonthe
# Processing Record 34 of Set 5 | concarneau
# Processing Record 35 of Set 5 | sola
# Processing Record 36 of Set 5 | sibutad
# Processing Record 37 of Set 5 | rio cuarto
# Processing Record 38 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 5 | borogontsy
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | wakkanai
# Processing Record 42 of Set 5 | maniitsoq
# Processing Record 43 of Set 5 | omsukchan
# Processing Record 44 of Set 5 | makokou
# Processing Record 45 of Set 5 | vao
# Processing Record 46 of Set 5 | mandalgovi
# Processing Record 47 of Set 5 | alekseyevka
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | viedma
# Processing Record 50 of Set 5 | domoni
# Processing Record 1 of Set 6 | mount isa
# Processing Record 2 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 6 | voh
# Processing Record 4 of Set 6 | ilhabela
# Processing Record 5 of Set 6 | klaksvik
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | yinchuan
# Processing Record 8 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | izhma
# Processing Record 11 of Set 6 | russellville
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | develi
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | cabo san lucas
# Processing Record 16 of Set 6 | nova olimpia
# Processing Record 17 of Set 6 | jimo
# Processing Record 18 of Set 6 | mao
# Processing Record 19 of Set 6 | sorrento
# Processing Record 20 of Set 6 | makhinjauri
# Processing Record 21 of Set 6 | honiara
# Processing Record 22 of Set 6 | haileybury
# Processing Record 23 of Set 6 | dores do indaia
# Processing Record 24 of Set 6 | ashtian
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | gualaquiza
# Processing Record 27 of Set 6 | dawlatabad
# Processing Record 28 of Set 6 | namatanai
# Processing Record 29 of Set 6 | kasongo-lunda
# Processing Record 30 of Set 6 | pindwara
# Processing Record 31 of Set 6 | saskylakh
# Processing Record 32 of Set 6 | nytva
# Processing Record 33 of Set 6 | mackay
# Processing Record 34 of Set 6 | jaragua
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | sorong
# Processing Record 37 of Set 6 | ercis
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | bushehr
# Processing Record 41 of Set 6 | gigmoto
# Processing Record 42 of Set 6 | sitrah
# Processing Record 43 of Set 6 | butaritari
# Processing Record 44 of Set 6 | bethel
# Processing Record 45 of Set 6 | olyka
# Processing Record 46 of Set 6 | daitari
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | camacari
# Processing Record 49 of Set 6 | areosa
# Processing Record 50 of Set 6 | cam ranh
# Processing Record 1 of Set 7 | lipin bor
# Processing Record 2 of Set 7 | atbasar
# Processing Record 3 of Set 7 | pueblo nuevo
# Processing Record 4 of Set 7 | san matias
# Processing Record 5 of Set 7 | niort
# Processing Record 6 of Set 7 | ponta do sol
# Processing Record 7 of Set 7 | portree
# Processing Record 8 of Set 7 | katsuura
# Processing Record 9 of Set 7 | bulaevo
# Processing Record 10 of Set 7 | dhamnod
# Processing Record 11 of Set 7 | appenzell
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | pangody
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | san pedro de macoris
# Processing Record 16 of Set 7 | jamnah
# City not found. Skipping...
# Processing Record 17 of Set 7 | forbes
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | sydney
# Processing Record 22 of Set 7 | batemans bay
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | port blair
# Processing Record 25 of Set 7 | dingle
# Processing Record 26 of Set 7 | college
# Processing Record 27 of Set 7 | samut prakan
# Processing Record 28 of Set 7 | tecpan
# Processing Record 29 of Set 7 | biloxi
# Processing Record 30 of Set 7 | souillac
# Processing Record 31 of Set 7 | agustin codazzi
# Processing Record 32 of Set 7 | puerto madero
# Processing Record 33 of Set 7 | oranjemund
# Processing Record 34 of Set 7 | cap malheureux
# Processing Record 35 of Set 7 | bageshwar
# Processing Record 36 of Set 7 | sao filipe
# Processing Record 37 of Set 7 | ocala
# Processing Record 38 of Set 7 | matara
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | ndago
# Processing Record 41 of Set 7 | boca do acre
# Processing Record 42 of Set 7 | la palma
# Processing Record 43 of Set 7 | portland
# Processing Record 44 of Set 7 | boulder city
# Processing Record 45 of Set 7 | lerwick
# Processing Record 46 of Set 7 | tuxpan
# Processing Record 47 of Set 7 | carutapera
# Processing Record 48 of Set 7 | port keats
# Processing Record 49 of Set 7 | umm lajj
# Processing Record 50 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 8 | san andres
# Processing Record 2 of Set 8 | miri
# Processing Record 3 of Set 8 | koumra
# Processing Record 4 of Set 8 | nome
# Processing Record 5 of Set 8 | kailua
# Processing Record 6 of Set 8 | deputatskiy
# Processing Record 7 of Set 8 | miles city
# Processing Record 8 of Set 8 | san vicente
# Processing Record 9 of Set 8 | hami
# Processing Record 10 of Set 8 | aklavik
# Processing Record 11 of Set 8 | shenzhen
# Processing Record 12 of Set 8 | suoyarvi
# Processing Record 13 of Set 8 | puerto ayacucho
# Processing Record 14 of Set 8 | ishigaki
# Processing Record 15 of Set 8 | sibu
# Processing Record 16 of Set 8 | cabedelo
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 8 | northam
# Processing Record 20 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 8 | xingyi
# Processing Record 22 of Set 8 | iznik
# Processing Record 23 of Set 8 | berdigestyakh
# Processing Record 24 of Set 8 | shurugwi
# Processing Record 25 of Set 8 | zabaykalsk
# Processing Record 26 of Set 8 | beira
# Processing Record 27 of Set 8 | luena
# Processing Record 28 of Set 8 | baie-comeau
# Processing Record 29 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 8 | tagusao
# Processing Record 31 of Set 8 | neuquen
# Processing Record 32 of Set 8 | yerbogachen
# Processing Record 33 of Set 8 | xining
# Processing Record 34 of Set 8 | kidal
# Processing Record 35 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 8 | svobodnyy
# Processing Record 37 of Set 8 | niquelandia
# Processing Record 38 of Set 8 | santa cruz
# Processing Record 39 of Set 8 | hofn
# Processing Record 40 of Set 8 | taltal
# Processing Record 41 of Set 8 | ewa beach
# Processing Record 42 of Set 8 | niamey
# Processing Record 43 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 8 | suruc
# Processing Record 45 of Set 8 | sorland
# Processing Record 46 of Set 8 | santo amaro da imperatriz
# Processing Record 47 of Set 8 | passo de camaragibe
# Processing Record 48 of Set 8 | seydi
# Processing Record 49 of Set 8 | rabo de peixe
# Processing Record 50 of Set 8 | kilindoni
# Processing Record 1 of Set 9 | mayumba
# Processing Record 2 of Set 9 | mooi river
# City not found. Skipping...
# Processing Record 3 of Set 9 | ibra
# Processing Record 4 of Set 9 | buluang
# Processing Record 5 of Set 9 | kyra
# Processing Record 6 of Set 9 | katangli
# Processing Record 7 of Set 9 | waipawa
# Processing Record 8 of Set 9 | gamba
# Processing Record 9 of Set 9 | havre-saint-pierre
# Processing Record 10 of Set 9 | cantagallo
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | kyren
# Processing Record 13 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | novobirilyussy
# Processing Record 16 of Set 9 | sawakin
# Processing Record 17 of Set 9 | rumoi
# Processing Record 18 of Set 9 | tiznit
# Processing Record 19 of Set 9 | fatezh
# Processing Record 20 of Set 9 | canberra
# Processing Record 21 of Set 9 | kruisfontein
# Processing Record 22 of Set 9 | kaspiyskiy
# Processing Record 23 of Set 9 | bloemfontein
# Processing Record 24 of Set 9 | keita
# Processing Record 25 of Set 9 | najran
# Processing Record 26 of Set 9 | tazovskiy
# Processing Record 27 of Set 9 | grinnell
# Processing Record 28 of Set 9 | copiapo
# Processing Record 29 of Set 9 | phan thiet
# Processing Record 30 of Set 9 | price
# Processing Record 31 of Set 9 | santa rosa
# Processing Record 32 of Set 9 | saquena
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | tripoli
# Processing Record 36 of Set 9 | kangaatsiaq
# Processing Record 37 of Set 9 | mont-dore
# Processing Record 38 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 9 | catamarca
# Processing Record 40 of Set 9 | wolgast
# Processing Record 41 of Set 9 | kota belud
# Processing Record 42 of Set 9 | figeac
# Processing Record 43 of Set 9 | banda aceh
# Processing Record 44 of Set 9 | quatre cocos
# Processing Record 45 of Set 9 | kokoda
# Processing Record 46 of Set 9 | coquimbo
# Processing Record 47 of Set 9 | chicama
# Processing Record 48 of Set 9 | puerto penasco
# Processing Record 49 of Set 9 | san borja
# Processing Record 50 of Set 9 | gallup
# Processing Record 1 of Set 10 | hamilton
# Processing Record 2 of Set 10 | matagami
# Processing Record 3 of Set 10 | la ronge
# Processing Record 4 of Set 10 | herat
# Processing Record 5 of Set 10 | road town
# Processing Record 6 of Set 10 | cacimba de dentro
# Processing Record 7 of Set 10 | jackson
# Processing Record 8 of Set 10 | aksay
# Processing Record 9 of Set 10 | scarborough
# Processing Record 10 of Set 10 | oussouye
# Processing Record 11 of Set 10 | porto santo
# Processing Record 12 of Set 10 | melton
# Processing Record 13 of Set 10 | henties bay
# Processing Record 14 of Set 10 | lae
# Processing Record 15 of Set 10 | kharitonovo
# Processing Record 16 of Set 10 | cayenne
# Processing Record 17 of Set 10 | priiskovyy
# Processing Record 18 of Set 10 | chuy
# Processing Record 19 of Set 10 | lukovetskiy
# Processing Record 20 of Set 10 | winneba
# Processing Record 21 of Set 10 | koroni
# Processing Record 22 of Set 10 | clermont
# Processing Record 23 of Set 10 | paris
# Processing Record 24 of Set 10 | angra
# City not found. Skipping...
# Processing Record 25 of Set 10 | ban nahin
# Processing Record 26 of Set 10 | asau
# Processing Record 27 of Set 10 | ponta delgada
# Processing Record 28 of Set 10 | progreso
# Processing Record 29 of Set 10 | longyearbyen
# Processing Record 30 of Set 10 | sendhwa
# Processing Record 31 of Set 10 | mezen
# Processing Record 32 of Set 10 | erzin
# Processing Record 33 of Set 10 | zhob
# Processing Record 34 of Set 10 | saint-joseph
# Processing Record 35 of Set 10 | clonakilty
# Processing Record 36 of Set 10 | simplicio mendes
# Processing Record 37 of Set 10 | bangsund
# Processing Record 38 of Set 10 | xai-xai
# Processing Record 39 of Set 10 | hailar
# Processing Record 40 of Set 10 | duz
# City not found. Skipping...
# Processing Record 41 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 42 of Set 10 | mvuma
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | chiredzi
# Processing Record 45 of Set 10 | airai
# Processing Record 46 of Set 10 | sharjah
# Processing Record 47 of Set 10 | mikhaylovka
# Processing Record 48 of Set 10 | pimentel
# Processing Record 49 of Set 10 | alta floresta
# Processing Record 50 of Set 10 | hervey bay
# Processing Record 1 of Set 11 | ixtapa
# Processing Record 2 of Set 11 | sokoto
# Processing Record 3 of Set 11 | amarante do maranhao
# Processing Record 4 of Set 11 | newburgh
# Processing Record 5 of Set 11 | labuhan
# Processing Record 6 of Set 11 | olinda
# Processing Record 7 of Set 11 | aquiraz
# Processing Record 8 of Set 11 | khonsar
# City not found. Skipping...
# Processing Record 9 of Set 11 | kenora
# Processing Record 10 of Set 11 | kiama
# Processing Record 11 of Set 11 | lengshuitan
# Processing Record 12 of Set 11 | dutse
# Processing Record 13 of Set 11 | naples
# Processing Record 14 of Set 11 | felipe carrillo puerto
# Processing Record 15 of Set 11 | bonavista
# Processing Record 16 of Set 11 | laguna
# Processing Record 17 of Set 11 | acapulco
# Processing Record 18 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 19 of Set 11 | kerema
# Processing Record 20 of Set 11 | kampot
# Processing Record 21 of Set 11 | tabuk
# Processing Record 22 of Set 11 | barcelos
# Processing Record 23 of Set 11 | itarema
# Processing Record 24 of Set 11 | lamar
# Processing Record 25 of Set 11 | montrose
# Processing Record 26 of Set 11 | vangaindrano
# Processing Record 27 of Set 11 | manavgat
# Processing Record 28 of Set 11 | inuvik
# Processing Record 29 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 11 | male
# Processing Record 31 of Set 11 | saryagash
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | kurilsk
# Processing Record 34 of Set 11 | tanda
# Processing Record 35 of Set 11 | badnawar
# Processing Record 36 of Set 11 | vanimo
# Processing Record 37 of Set 11 | astorga
# Processing Record 38 of Set 11 | stoughton
# Processing Record 39 of Set 11 | north myrtle beach
# Processing Record 40 of Set 11 | wewak
# Processing Record 41 of Set 11 | manado
# Processing Record 42 of Set 11 | mutum
# Processing Record 43 of Set 11 | narsaq
# Processing Record 44 of Set 11 | buraydah
# Processing Record 45 of Set 11 | yambio
# Processing Record 46 of Set 11 | burila mare
# Processing Record 47 of Set 11 | trairi
# Processing Record 48 of Set 11 | codajas
# Processing Record 49 of Set 11 | mumford
# Processing Record 50 of Set 11 | sambava
# Processing Record 1 of Set 12 | marshfield
# Processing Record 2 of Set 12 | senno
# Processing Record 3 of Set 12 | grindavik
# Processing Record 4 of Set 12 | nouadhibou
# Processing Record 5 of Set 12 | khasan
# Processing Record 6 of Set 12 | jungapeo
# Processing Record 7 of Set 12 | tutoia
# Processing Record 8 of Set 12 | talnakh
# Processing Record 9 of Set 12 | luwuk
# Processing Record 10 of Set 12 | guano
# Processing Record 11 of Set 12 | moussoro
# Processing Record 12 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 12 | ginir
# Processing Record 14 of Set 12 | kyaikkami
# Processing Record 15 of Set 12 | pelym
# Processing Record 16 of Set 12 | pacific grove
# Processing Record 17 of Set 12 | verkhnyaya inta
# Processing Record 18 of Set 12 | flin flon
# Processing Record 19 of Set 12 | phanom thuan
# Processing Record 20 of Set 12 | ayr
# Processing Record 21 of Set 12 | sisimiut
# Processing Record 22 of Set 12 | sikasso
# Processing Record 23 of Set 12 | kieta
# Processing Record 24 of Set 12 | fortuna
# Processing Record 25 of Set 12 | taoudenni
# Processing Record 26 of Set 12 | sulangan
# Processing Record 27 of Set 12 | tucuman
# Processing Record 28 of Set 12 | karachi
# Processing Record 29 of Set 12 | bilibino
# Processing Record 30 of Set 12 | salekhard
# Processing Record 31 of Set 12 | penzance
# Processing Record 32 of Set 12 | bermeo
# Processing Record 33 of Set 12 | whitefish
# Processing Record 34 of Set 12 | saint-louis
# Processing Record 35 of Set 12 | inhambane
# Processing Record 36 of Set 12 | derzhavinsk
# Processing Record 37 of Set 12 | russell
# Processing Record 38 of Set 12 | shahrud
# Processing Record 39 of Set 12 | rio gallegos
# Processing Record 40 of Set 12 | okhotsk
# Processing Record 41 of Set 12 | vilyuysk
# Processing Record 42 of Set 12 | seoul
# Processing Record 43 of Set 12 | ambon
# Processing Record 44 of Set 12 | alugan
# Processing Record 45 of Set 12 | sur
# Processing Record 46 of Set 12 | diamantina
# Processing Record 47 of Set 12 | honolulu
# Processing Record 48 of Set 12 | gull lake
# Processing Record 49 of Set 12 | hefei
# Processing Record 50 of Set 12 | anadyr
# Processing Record 1 of Set 13 | puerto escondido
# Processing Record 2 of Set 13 | san jeronimo
# Processing Record 3 of Set 13 | camacha
# Processing Record 4 of Set 13 | romitan
# Processing Record 5 of Set 13 | lodwar
# Processing Record 6 of Set 13 | vestmannaeyjar
# Processing Record 7 of Set 13 | nemuro
# Processing Record 8 of Set 13 | alice springs
# Processing Record 9 of Set 13 | koslan
# Processing Record 10 of Set 13 | george
# Processing Record 11 of Set 13 | zabol
# Processing Record 12 of Set 13 | fort nelson
# Processing Record 13 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 13 | adrar
# Processing Record 15 of Set 13 | semnan
# Processing Record 16 of Set 13 | solnechnyy
# Processing Record 17 of Set 13 | pitimbu
# Processing Record 18 of Set 13 | dabat
# Processing Record 19 of Set 13 | nyzhni sirohozy
# Processing Record 20 of Set 13 | sao joao da barra
# Processing Record 21 of Set 13 | ovsyanka
# Processing Record 22 of Set 13 | scalloway
# City not found. Skipping...
# Processing Record 23 of Set 13 | rybachiy
# Processing Record 24 of Set 13 | kungurtug
# Processing Record 25 of Set 13 | pyay
# Processing Record 26 of Set 13 | ust-nera
# Processing Record 27 of Set 13 | bud
# Processing Record 28 of Set 13 | longview
# Processing Record 29 of Set 13 | te anau
# Processing Record 30 of Set 13 | tiarei
# Processing Record 31 of Set 13 | nehe
# Processing Record 32 of Set 13 | kodinsk
# Processing Record 33 of Set 13 | santander
# Processing Record 34 of Set 13 | krasnyye chetai
# Processing Record 35 of Set 13 | soure
# Processing Record 36 of Set 13 | punta cardon
# Processing Record 37 of Set 13 | kulhudhuffushi
# Processing Record 38 of Set 13 | atalaya
# Processing Record 39 of Set 13 | ascension
# Processing Record 40 of Set 13 | korla
# Processing Record 41 of Set 13 | novomikhaylovskiy
# Processing Record 42 of Set 13 | leninskoye
# Processing Record 43 of Set 13 | sao miguel do araguaia
# Processing Record 44 of Set 13 | duncan
# Processing Record 45 of Set 13 | vila do maio
# Processing Record 46 of Set 13 | gizo
# Processing Record 47 of Set 13 | cimarron hills
# Processing Record 48 of Set 13 | talara
# Processing Record 49 of Set 13 | markova
# Processing Record 50 of Set 13 | cagliliog
# Processing Record 1 of Set 14 | nampa
# Processing Record 2 of Set 14 | garowe
# Processing Record 3 of Set 14 | cookeville
# Processing Record 4 of Set 14 | north platte
# Processing Record 5 of Set 14 | hargeysa
# Processing Record 6 of Set 14 | shakhtinsk
# Processing Record 7 of Set 14 | kaeo
# Processing Record 8 of Set 14 | kozhva
# Processing Record 9 of Set 14 | nalut
# Processing Record 10 of Set 14 | dzhebariki-khaya
# Processing Record 11 of Set 14 | huarmey
# Processing Record 12 of Set 14 | enshi
# Processing Record 13 of Set 14 | porto velho
# Processing Record 14 of Set 14 | udachnyy
# Processing Record 15 of Set 14 | cherskiy
# Processing Record 16 of Set 14 | corowa
# Processing Record 17 of Set 14 | nsoko
# Processing Record 18 of Set 14 | kattivakkam
# Processing Record 19 of Set 14 | teguldet
# Processing Record 20 of Set 14 | krasnoslobodsk
# Processing Record 21 of Set 14 | komsomolskiy
# Processing Record 22 of Set 14 | pouebo
# Processing Record 23 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 14 | new albany
# Processing Record 25 of Set 14 | pervomayskiy
# Processing Record 26 of Set 14 | half moon bay
# Processing Record 27 of Set 14 | saint anthony
# Processing Record 28 of Set 14 | aja
# Processing Record 29 of Set 14 | guadalupe victoria
# Processing Record 30 of Set 14 | cap-aux-meules
# Processing Record 31 of Set 14 | les cayes
# Processing Record 32 of Set 14 | poso
# Processing Record 33 of Set 14 | sumbawanga
# Processing Record 34 of Set 14 | micheweni
# Processing Record 35 of Set 14 | turukhansk
# Processing Record 36 of Set 14 | bahia blanca
# Processing Record 37 of Set 14 | dahuk
# Processing Record 38 of Set 14 | yarim
# Processing Record 39 of Set 14 | turkistan
# Processing Record 40 of Set 14 | callaguip
# Processing Record 41 of Set 14 | tallahassee
# Processing Record 42 of Set 14 | bubaque
# Processing Record 43 of Set 14 | baykit
# Processing Record 44 of Set 14 | kavaratti
# Processing Record 45 of Set 14 | zambezi
# Processing Record 46 of Set 14 | trincomalee
# Processing Record 47 of Set 14 | menongue
# Processing Record 48 of Set 14 | north bend
# Processing Record 49 of Set 14 | gravdal
# Processing Record 50 of Set 14 | hudson bay
# Processing Record 1 of Set 15 | corbu
# Processing Record 2 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 3 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 15 | kaseda
# Processing Record 5 of Set 15 | geilo
# Processing Record 6 of Set 15 | sena madureira
# Processing Record 7 of Set 15 | gerash
# Processing Record 8 of Set 15 | kuvshinovo
# Processing Record 9 of Set 15 | zulueta
# Processing Record 10 of Set 15 | birjand
# Processing Record 11 of Set 15 | floro
# Processing Record 12 of Set 15 | arboledas
# Processing Record 13 of Set 15 | geneva
# Processing Record 14 of Set 15 | fukue
# Processing Record 15 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 15 | chilia veche
# Processing Record 17 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | guanay
# Processing Record 19 of Set 15 | serebryansk
# Processing Record 20 of Set 15 | tual
# Processing Record 21 of Set 15 | vicuna
# Processing Record 22 of Set 15 | kontagora
# Processing Record 23 of Set 15 | itaituba
# Processing Record 24 of Set 15 | rock sound
# Processing Record 25 of Set 15 | houlung
# City not found. Skipping...
# Processing Record 26 of Set 15 | qasigiannguit
# Processing Record 27 of Set 15 | himora
# City not found. Skipping...
# Processing Record 28 of Set 15 | san carlos de bariloche
# Processing Record 29 of Set 15 | lavrentiya
# Processing Record 30 of Set 15 | san policarpo
# Processing Record 31 of Set 15 | thoen
# Processing Record 32 of Set 15 | bajil
# Processing Record 33 of Set 15 | salinopolis
# Processing Record 34 of Set 15 | sagar
# Processing Record 35 of Set 15 | staryy nadym
# Processing Record 36 of Set 15 | esil
# Processing Record 37 of Set 15 | yamada
# Processing Record 38 of Set 15 | arandis
# Processing Record 39 of Set 15 | port huron
# Processing Record 40 of Set 15 | altay
# Processing Record 41 of Set 15 | sussex
# Processing Record 42 of Set 15 | beloha
# Processing Record 43 of Set 15 | lima
# Processing Record 44 of Set 15 | morant bay
# Processing Record 45 of Set 15 | salacgriva
# Processing Record 46 of Set 15 | tilichiki
# Processing Record 47 of Set 15 | yumen
# Processing Record 48 of Set 15 | iskateley
# Processing Record 49 of Set 15 | maningrida
# Processing Record 50 of Set 15 | faya
# Processing Record 1 of Set 16 | dinajpur
# Processing Record 2 of Set 16 | berlevag
# Processing Record 3 of Set 16 | ravar
# Processing Record 4 of Set 16 | samba
# Processing Record 5 of Set 16 | porto novo
# Processing Record 6 of Set 16 | kendari
# Processing Record 7 of Set 16 | surt
# Processing Record 8 of Set 16 | millinocket
# Processing Record 9 of Set 16 | seguin
# Processing Record 10 of Set 16 | el carmen
# Processing Record 11 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 16 | saquarema
# Processing Record 13 of Set 16 | nangong
# Processing Record 14 of Set 16 | ahvaz
# Processing Record 15 of Set 16 | sistranda
# Processing Record 16 of Set 16 | waddan
# Processing Record 17 of Set 16 | nueva loja
# Processing Record 18 of Set 16 | nemours
# Processing Record 19 of Set 16 | muriwai beach
# Processing Record 20 of Set 16 | laredo
# Processing Record 21 of Set 16 | malakal
# Processing Record 22 of Set 16 | akyab
# Processing Record 23 of Set 16 | imelda
# Processing Record 24 of Set 16 | astoria
# Processing Record 25 of Set 16 | el faiyum
# City not found. Skipping...
# Processing Record 26 of Set 16 | rincon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Lompoc  34.64 -120.46     62.60        82           0        8.05
# 1       Busselton -33.65  115.33     48.99        82          80        1.77
# 2       Dhidhdhoo   6.88   73.10     82.85        79         100       14.70
# 3             Hit  33.64   42.83     94.23        13           0        5.57
# 4      Nikolskoye  59.70   30.79     64.40        48          20        6.71
# 5       Mogadishu   2.04   45.34     77.25        80          40       22.17
# 6      Bredasdorp -34.53   20.04     51.80        87           0        4.70
# 7     Villa Maria -32.41  -63.24     73.26        45          27       21.43
# 8  Saint-Philippe -21.36   55.77     69.80        77          75       17.22
# 9       Cape Town -33.93   18.42     60.01        82           0        2.24
#
#   Country Current Description                 Date
# 0      US           clear sky  2020-08-01 18:12:39
# 1      AU       broken clouds  2020-08-01 18:12:11
# 2      MV     overcast clouds  2020-08-01 18:13:03
# 3      IQ           clear sky  2020-08-01 18:13:03
# 4      RU          few clouds  2020-08-01 18:12:14
# 5      SO          light rain  2020-08-01 18:12:22
# 6      ZA           clear sky  2020-08-01 18:12:10
# 7      AR    scattered clouds  2020-08-01 18:13:03
# 8      RE       broken clouds  2020-08-01 18:12:14
# 9      ZA           clear sky  2020-08-01 18:12:13

# %%
new_coloum_order =["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_coloum_order]
city_data_df.head()
# Out:
#          City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0      Lompoc      US  2020-08-01 18:12:39  34.64 -120.46     62.60        82
# 1   Busselton      AU  2020-08-01 18:12:11 -33.65  115.33     48.99        82
# 2   Dhidhdhoo      MV  2020-08-01 18:13:03   6.88   73.10     82.85        79
# 3         Hit      IQ  2020-08-01 18:13:03  33.64   42.83     94.23        13
# 4  Nikolskoye      RU  2020-08-01 18:12:14  59.70   30.79     64.40        48
#
#    Cloudiness  Wind Speed Current Description
# 0           0        8.05           clear sky
# 1          80        1.77       broken clouds
# 2         100       14.70     overcast clouds
# 3           0        5.57           clear sky
# 4          20        6.71          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
