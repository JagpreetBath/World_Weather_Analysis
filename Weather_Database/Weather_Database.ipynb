# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date,})
        
#"Current Description": city_weather_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | walvis bay
# Processing Record 4 of Set 1 | bubaque
# Processing Record 5 of Set 1 | paragominas
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | gombe
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | nuuk
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | villa maria
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | lavrentiya
# Processing Record 26 of Set 1 | luang prabang
# Processing Record 27 of Set 1 | genthin
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | basoko
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | quisqueya
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | acapulco
# Processing Record 35 of Set 1 | broome
# Processing Record 36 of Set 1 | okha
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | marystown
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | gamba
# Processing Record 42 of Set 1 | itacare
# Processing Record 43 of Set 1 | emerald
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | fiesole
# Processing Record 47 of Set 1 | tilichiki
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | marsa matruh
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | buin
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | tezu
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | beringovskiy
# Processing Record 19 of Set 2 | jalu
# Processing Record 20 of Set 2 | te anau
# Processing Record 21 of Set 2 | sampit
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | yar-sale
# Processing Record 24 of Set 2 | krasnohrad
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | addi ugri
# City not found. Skipping...
# Processing Record 27 of Set 2 | biak
# Processing Record 28 of Set 2 | chinsali
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | tlahualilo
# City not found. Skipping...
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | rawlins
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | tura
# Processing Record 37 of Set 2 | doha
# Processing Record 38 of Set 2 | karaton
# Processing Record 39 of Set 2 | garowe
# Processing Record 40 of Set 2 | izhmorskiy
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | kalmunai
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | mayo
# Processing Record 45 of Set 2 | willmar
# Processing Record 46 of Set 2 | kovdor
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | kaseda
# Processing Record 3 of Set 3 | puri
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | omboue
# Processing Record 9 of Set 3 | rawson
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | bandarbeyla
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | sambava
# Processing Record 15 of Set 3 | kapoeta
# Processing Record 16 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | strezhevoy
# Processing Record 19 of Set 3 | hammerfest
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | red bluff
# Processing Record 22 of Set 3 | raudeberg
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | constitucion
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | san clemente
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | palmerston
# Processing Record 30 of Set 3 | sabha
# Processing Record 31 of Set 3 | agadez
# Processing Record 32 of Set 3 | belmonte
# Processing Record 33 of Set 3 | beloha
# Processing Record 34 of Set 3 | burlington
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | bogdanovich
# Processing Record 37 of Set 3 | sinnamary
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | belle glade
# Processing Record 40 of Set 3 | yeppoon
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | union
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | mandalgovi
# Processing Record 45 of Set 3 | harper
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | asau
# Processing Record 48 of Set 3 | lata
# Processing Record 49 of Set 3 | ust-kut
# Processing Record 50 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | gravdal
# Processing Record 3 of Set 4 | pasighat
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | port lincoln
# Processing Record 6 of Set 4 | road town
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | dongsheng
# Processing Record 9 of Set 4 | qandala
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | cockburn town
# Processing Record 12 of Set 4 | fort nelson
# Processing Record 13 of Set 4 | polazna
# Processing Record 14 of Set 4 | launceston
# Processing Record 15 of Set 4 | akyab
# Processing Record 16 of Set 4 | hamilton
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | taywarah
# Processing Record 20 of Set 4 | lubao
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | kloulklubed
# Processing Record 24 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | amapa
# Processing Record 26 of Set 4 | jalingo
# Processing Record 27 of Set 4 | pitimbu
# Processing Record 28 of Set 4 | carrollton
# Processing Record 29 of Set 4 | nadym
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | qaqortoq
# Processing Record 32 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 4 | hovd
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | hambantota
# Processing Record 36 of Set 4 | nabire
# Processing Record 37 of Set 4 | margate
# Processing Record 38 of Set 4 | kaduna
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | enumclaw
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | esperance
# Processing Record 43 of Set 4 | yinchuan
# Processing Record 44 of Set 4 | port hardy
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | mahon
# Processing Record 47 of Set 4 | buala
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | salme
# Processing Record 50 of Set 4 | gijon
# Processing Record 1 of Set 5 | sistranda
# Processing Record 2 of Set 5 | sindor
# Processing Record 3 of Set 5 | vasai
# Processing Record 4 of Set 5 | sao gabriel da cachoeira
# Processing Record 5 of Set 5 | gurupa
# Processing Record 6 of Set 5 | elliot
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | maragogi
# Processing Record 10 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 5 | svetlogorsk
# Processing Record 12 of Set 5 | alyangula
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | williams lake
# Processing Record 15 of Set 5 | kurumkan
# Processing Record 16 of Set 5 | carandai
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | tres arroyos
# Processing Record 19 of Set 5 | ende
# Processing Record 20 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 21 of Set 5 | hobyo
# Processing Record 22 of Set 5 | leh
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | isangel
# Processing Record 25 of Set 5 | krasnyy chikoy
# Processing Record 26 of Set 5 | east london
# Processing Record 27 of Set 5 | fort morgan
# Processing Record 28 of Set 5 | dolores
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | qasigiannguit
# Processing Record 31 of Set 5 | ulaanbaatar
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | xining
# Processing Record 36 of Set 5 | rodrigues alves
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | hudiksvall
# Processing Record 39 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 5 | angoche
# Processing Record 41 of Set 5 | dinguiraye
# Processing Record 42 of Set 5 | olafsvik
# Processing Record 43 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 5 | orsha
# Processing Record 45 of Set 5 | piacabucu
# Processing Record 46 of Set 5 | gilgit
# Processing Record 47 of Set 5 | lalibela
# Processing Record 48 of Set 5 | cerro cama
# Processing Record 49 of Set 5 | sur
# Processing Record 50 of Set 5 | kyabe
# Processing Record 1 of Set 6 | asaba
# Processing Record 2 of Set 6 | makubetsu
# Processing Record 3 of Set 6 | perama
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | mossendjo
# Processing Record 7 of Set 6 | batagay
# Processing Record 8 of Set 6 | yatou
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | bintulu
# Processing Record 11 of Set 6 | namatanai
# Processing Record 12 of Set 6 | tukrah
# Processing Record 13 of Set 6 | san carlos de bariloche
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | bayji
# Processing Record 16 of Set 6 | mosquera
# Processing Record 17 of Set 6 | flinders
# Processing Record 18 of Set 6 | seoul
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | santa rosalia
# Processing Record 22 of Set 6 | vestmannaeyjar
# Processing Record 23 of Set 6 | santa isabel do rio negro
# Processing Record 24 of Set 6 | mareeba
# Processing Record 25 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 6 | riyadh
# Processing Record 27 of Set 6 | tamworth
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | pangnirtung
# Processing Record 30 of Set 6 | mao
# Processing Record 31 of Set 6 | raga
# Processing Record 32 of Set 6 | chapais
# Processing Record 33 of Set 6 | cap malheureux
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | bundibugyo
# Processing Record 37 of Set 6 | kudahuvadhoo
# Processing Record 38 of Set 6 | mineiros
# Processing Record 39 of Set 6 | mayumba
# Processing Record 40 of Set 6 | whyalla
# Processing Record 41 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 6 | svetlyy
# Processing Record 43 of Set 6 | charters towers
# Processing Record 44 of Set 6 | boueni
# Processing Record 45 of Set 6 | carutapera
# Processing Record 46 of Set 6 | maridi
# Processing Record 47 of Set 6 | voronovytsya
# Processing Record 48 of Set 6 | delta
# Processing Record 49 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 6 | waw
# Processing Record 1 of Set 7 | hithadhoo
# Processing Record 2 of Set 7 | butaritari
# Processing Record 3 of Set 7 | carauari
# Processing Record 4 of Set 7 | atasu
# Processing Record 5 of Set 7 | pingliang
# Processing Record 6 of Set 7 | karasjok
# Processing Record 7 of Set 7 | novopokrovka
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | saldanha
# Processing Record 10 of Set 7 | kindu
# Processing Record 11 of Set 7 | vestmanna
# Processing Record 12 of Set 7 | sola
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | alpena
# Processing Record 15 of Set 7 | kamareddi
# Processing Record 16 of Set 7 | nakusp
# Processing Record 17 of Set 7 | yerbogachen
# Processing Record 18 of Set 7 | lashio
# Processing Record 19 of Set 7 | sawakin
# Processing Record 20 of Set 7 | goundam
# Processing Record 21 of Set 7 | salalah
# Processing Record 22 of Set 7 | vardo
# Processing Record 23 of Set 7 | eureka
# Processing Record 24 of Set 7 | ajdabiya
# Processing Record 25 of Set 7 | pangoa
# Processing Record 26 of Set 7 | mount gambier
# Processing Record 27 of Set 7 | marquette
# Processing Record 28 of Set 7 | mount isa
# Processing Record 29 of Set 7 | mino
# Processing Record 30 of Set 7 | ahuimanu
# Processing Record 31 of Set 7 | salinopolis
# Processing Record 32 of Set 7 | sevnica
# Processing Record 33 of Set 7 | dwarka
# Processing Record 34 of Set 7 | dano
# Processing Record 35 of Set 7 | tual
# Processing Record 36 of Set 7 | osterburg
# Processing Record 37 of Set 7 | minab
# Processing Record 38 of Set 7 | lebu
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | urumqi
# Processing Record 42 of Set 7 | lillehammer
# Processing Record 43 of Set 7 | tahe
# Processing Record 44 of Set 7 | ambilobe
# Processing Record 45 of Set 7 | vikulovo
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | tecoanapa
# Processing Record 48 of Set 7 | southbridge
# Processing Record 49 of Set 7 | springfield
# Processing Record 50 of Set 7 | dombarovskiy
# Processing Record 1 of Set 8 | dickinson
# Processing Record 2 of Set 8 | nyurba
# Processing Record 3 of Set 8 | ternate
# Processing Record 4 of Set 8 | ziyamet
# City not found. Skipping...
# Processing Record 5 of Set 8 | uni
# Processing Record 6 of Set 8 | coahuayana
# Processing Record 7 of Set 8 | afsin
# Processing Record 8 of Set 8 | huarmey
# Processing Record 9 of Set 8 | evensk
# Processing Record 10 of Set 8 | longyearbyen
# Processing Record 11 of Set 8 | soyo
# Processing Record 12 of Set 8 | yele
# Processing Record 13 of Set 8 | inhambane
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | mwinilunga
# Processing Record 16 of Set 8 | mancio lima
# Processing Record 17 of Set 8 | ponta delgada
# Processing Record 18 of Set 8 | talara
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | nador
# Processing Record 21 of Set 8 | turayf
# Processing Record 22 of Set 8 | provideniya
# Processing Record 23 of Set 8 | peabiru
# Processing Record 24 of Set 8 | gusino
# Processing Record 25 of Set 8 | aykhal
# Processing Record 26 of Set 8 | necochea
# Processing Record 27 of Set 8 | gawler
# Processing Record 28 of Set 8 | pervomayskoye
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | escanaba
# Processing Record 31 of Set 8 | keita
# Processing Record 32 of Set 8 | kurikka
# Processing Record 33 of Set 8 | kieta
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | srednekolymsk
# Processing Record 36 of Set 8 | carahue
# Processing Record 37 of Set 8 | campoverde
# Processing Record 38 of Set 8 | chuy
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | ribeira grande
# Processing Record 41 of Set 8 | broken hill
# Processing Record 42 of Set 8 | ottawa
# Processing Record 43 of Set 8 | uvat
# Processing Record 44 of Set 8 | porto walter
# Processing Record 45 of Set 8 | suntar
# Processing Record 46 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | entebbe
# Processing Record 49 of Set 8 | paredon
# Processing Record 50 of Set 8 | wagar
# Processing Record 1 of Set 9 | sobolevo
# Processing Record 2 of Set 9 | moose factory
# Processing Record 3 of Set 9 | lilongwe
# Processing Record 4 of Set 9 | kurya
# Processing Record 5 of Set 9 | chulym
# Processing Record 6 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 9 | abha
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | high level
# Processing Record 10 of Set 9 | kavaratti
# Processing Record 11 of Set 9 | russell
# Processing Record 12 of Set 9 | nome
# Processing Record 13 of Set 9 | richards bay
# Processing Record 14 of Set 9 | kidal
# Processing Record 15 of Set 9 | marsabit
# Processing Record 16 of Set 9 | poya
# Processing Record 17 of Set 9 | morant bay
# Processing Record 18 of Set 9 | mahibadhoo
# Processing Record 19 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 9 | karpogory
# Processing Record 22 of Set 9 | sept-iles
# Processing Record 23 of Set 9 | la palma
# Processing Record 24 of Set 9 | beba
# Processing Record 25 of Set 9 | ambulu
# Processing Record 26 of Set 9 | siniscola
# Processing Record 27 of Set 9 | touros
# Processing Record 28 of Set 9 | miura
# Processing Record 29 of Set 9 | atascadero
# Processing Record 30 of Set 9 | yaan
# Processing Record 31 of Set 9 | honiara
# Processing Record 32 of Set 9 | havre-saint-pierre
# Processing Record 33 of Set 9 | vuktyl
# Processing Record 34 of Set 9 | makakilo city
# Processing Record 35 of Set 9 | ankazoabo
# Processing Record 36 of Set 9 | le port
# Processing Record 37 of Set 9 | samarkand
# Processing Record 38 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 9 | nelson bay
# Processing Record 41 of Set 9 | conway
# Processing Record 42 of Set 9 | ratchaburi
# Processing Record 43 of Set 9 | abnub
# Processing Record 44 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 9 | haikou
# Processing Record 46 of Set 9 | taoudenni
# Processing Record 47 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 48 of Set 9 | sioux lookout
# Processing Record 49 of Set 9 | masvingo
# Processing Record 50 of Set 9 | egvekinot
# Processing Record 1 of Set 10 | beaverlodge
# Processing Record 2 of Set 10 | narsaq
# Processing Record 3 of Set 10 | atar
# Processing Record 4 of Set 10 | slave lake
# Processing Record 5 of Set 10 | ixtapa
# Processing Record 6 of Set 10 | weligama
# Processing Record 7 of Set 10 | merauke
# Processing Record 8 of Set 10 | manokwari
# Processing Record 9 of Set 10 | vostok
# Processing Record 10 of Set 10 | ler
# Processing Record 11 of Set 10 | ossora
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | carnarvon
# Processing Record 14 of Set 10 | krasnoye
# Processing Record 15 of Set 10 | gobabis
# Processing Record 16 of Set 10 | bilibino
# Processing Record 17 of Set 10 | krasnaya gorka
# Processing Record 18 of Set 10 | fayaoue
# Processing Record 19 of Set 10 | fortuna
# Processing Record 20 of Set 10 | sungaipenuh
# Processing Record 21 of Set 10 | tartagal
# Processing Record 22 of Set 10 | bentiu
# Processing Record 23 of Set 10 | sisimiut
# Processing Record 24 of Set 10 | san jose
# Processing Record 25 of Set 10 | ipixuna
# Processing Record 26 of Set 10 | dossor
# Processing Record 27 of Set 10 | aktau
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | delfzijl
# Processing Record 30 of Set 10 | lehi
# Processing Record 31 of Set 10 | ulladulla
# Processing Record 32 of Set 10 | panama city
# Processing Record 33 of Set 10 | south yuba city
# Processing Record 34 of Set 10 | opuwo
# Processing Record 35 of Set 10 | coihaique
# Processing Record 36 of Set 10 | westport
# Processing Record 37 of Set 10 | bitung
# Processing Record 38 of Set 10 | san patricio
# Processing Record 39 of Set 10 | boo
# Processing Record 40 of Set 10 | havelock
# Processing Record 41 of Set 10 | oranjestad
# Processing Record 42 of Set 10 | ardino
# Processing Record 43 of Set 10 | muli
# Processing Record 44 of Set 10 | khorixas
# Processing Record 45 of Set 10 | escalerillas
# Processing Record 46 of Set 10 | sar-e pul
# Processing Record 47 of Set 10 | brae
# Processing Record 48 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 10 | lochgilphead
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | dawlatabad
# Processing Record 2 of Set 11 | krasnoselkup
# Processing Record 3 of Set 11 | vila velha
# Processing Record 4 of Set 11 | nalut
# Processing Record 5 of Set 11 | arica
# Processing Record 6 of Set 11 | arlit
# Processing Record 7 of Set 11 | los llanos de aridane
# Processing Record 8 of Set 11 | cliza
# Processing Record 9 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 11 | pangody
# Processing Record 11 of Set 11 | abatskoye
# Processing Record 12 of Set 11 | maracaju
# Processing Record 13 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 11 | tazovskiy
# Processing Record 15 of Set 11 | horsham
# Processing Record 16 of Set 11 | ilebo
# Processing Record 17 of Set 11 | ojinaga
# Processing Record 18 of Set 11 | khuzdar
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | sabang
# Processing Record 21 of Set 11 | miri
# Processing Record 22 of Set 11 | sibu
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | mocuba
# Processing Record 25 of Set 11 | sabya
# Processing Record 26 of Set 11 | juneau
# Processing Record 27 of Set 11 | nemuro
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | turtas
# Processing Record 30 of Set 11 | bestobe
# Processing Record 31 of Set 11 | karratha
# Processing Record 32 of Set 11 | vitoria da conquista
# Processing Record 33 of Set 11 | lucapa
# Processing Record 34 of Set 11 | sterling
# Processing Record 35 of Set 11 | dwarahat
# Processing Record 36 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 11 | sarangani
# Processing Record 38 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 39 of Set 11 | karlskrona
# Processing Record 40 of Set 11 | sotnikovskoye
# Processing Record 41 of Set 11 | juba
# Processing Record 42 of Set 11 | bathsheba
# Processing Record 43 of Set 11 | luderitz
# Processing Record 44 of Set 11 | bugry
# Processing Record 45 of Set 11 | buraydah
# Processing Record 46 of Set 11 | geraldton
# Processing Record 47 of Set 11 | buenaventura
# Processing Record 48 of Set 11 | kayes
# Processing Record 49 of Set 11 | douentza
# Processing Record 50 of Set 11 | port blair
# Processing Record 1 of Set 12 | lekhovon
# City not found. Skipping...
# Processing Record 2 of Set 12 | nago
# Processing Record 3 of Set 12 | bandar-e lengeh
# Processing Record 4 of Set 12 | cedar city
# Processing Record 5 of Set 12 | storslett
# Processing Record 6 of Set 12 | northam
# Processing Record 7 of Set 12 | sakakah
# Processing Record 8 of Set 12 | apt
# Processing Record 9 of Set 12 | the valley
# Processing Record 10 of Set 12 | mirzapur
# Processing Record 11 of Set 12 | chicama
# Processing Record 12 of Set 12 | tutoia
# Processing Record 13 of Set 12 | cidreira
# Processing Record 14 of Set 12 | hami
# Processing Record 15 of Set 12 | uige
# Processing Record 16 of Set 12 | normandin
# Processing Record 17 of Set 12 | alexandria
# Processing Record 18 of Set 12 | sigli
# Processing Record 19 of Set 12 | gizo
# Processing Record 20 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 12 | koslan
# Processing Record 22 of Set 12 | burg
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | marsh harbour
# Processing Record 25 of Set 12 | christchurch
# Processing Record 26 of Set 12 | neyshabur
# Processing Record 27 of Set 12 | daru
# Processing Record 28 of Set 12 | erenhot
# Processing Record 29 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 12 | langsa
# Processing Record 31 of Set 12 | tongling
# Processing Record 32 of Set 12 | salinas
# Processing Record 33 of Set 12 | kailua
# Processing Record 34 of Set 12 | itaqui
# Processing Record 35 of Set 12 | chelmza
# Processing Record 36 of Set 12 | lethem
# Processing Record 37 of Set 12 | ribas do rio pardo
# Processing Record 38 of Set 12 | alihe
# Processing Record 39 of Set 12 | nsukka
# Processing Record 40 of Set 12 | saurimo
# Processing Record 41 of Set 12 | ranong
# Processing Record 42 of Set 12 | eydhafushi
# Processing Record 43 of Set 12 | lasa
# Processing Record 44 of Set 12 | catuday
# Processing Record 45 of Set 12 | goderich
# Processing Record 46 of Set 12 | talnakh
# Processing Record 47 of Set 12 | basco
# Processing Record 48 of Set 12 | praia da vitoria
# Processing Record 49 of Set 12 | mogadishu
# Processing Record 50 of Set 12 | benguela
# Processing Record 1 of Set 13 | trelew
# Processing Record 2 of Set 13 | porto franco
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | ziarat
# Processing Record 5 of Set 13 | lakatoro
# Processing Record 6 of Set 13 | shahgarh
# Processing Record 7 of Set 13 | pochutla
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | hay river
# Processing Record 10 of Set 13 | lubango
# Processing Record 11 of Set 13 | jiangkou
# Processing Record 12 of Set 13 | leningradskiy
# Processing Record 13 of Set 13 | barahona
# Processing Record 14 of Set 13 | santa vitoria
# Processing Record 15 of Set 13 | zapolyarnyy
# Processing Record 16 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 18 of Set 13 | contramaestre
# Processing Record 19 of Set 13 | havoysund
# Processing Record 20 of Set 13 | nguruka
# Processing Record 21 of Set 13 | brigantine
# Processing Record 22 of Set 13 | bara
# Processing Record 23 of Set 13 | sibiti
# Processing Record 24 of Set 13 | port-cartier
# Processing Record 25 of Set 13 | deer lake
# Processing Record 26 of Set 13 | yantal
# Processing Record 27 of Set 13 | upata
# Processing Record 28 of Set 13 | arman
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | naryan-mar
# Processing Record 31 of Set 13 | maymyo
# Processing Record 32 of Set 13 | verkhoyansk
# Processing Record 33 of Set 13 | cariati
# Processing Record 34 of Set 13 | marechal floriano
# Processing Record 35 of Set 13 | kuala terengganu
# Processing Record 36 of Set 13 | digha
# Processing Record 37 of Set 13 | mawlaik
# Processing Record 38 of Set 13 | quelimane
# Processing Record 39 of Set 13 | vangaindrano
# Processing Record 40 of Set 13 | grand gaube
# Processing Record 41 of Set 13 | bud
# Processing Record 42 of Set 13 | verkhnevilyuysk
# Processing Record 43 of Set 13 | ranau
# Processing Record 44 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 13 | fujin
# Processing Record 46 of Set 13 | taungdwingyi
# Processing Record 47 of Set 13 | grand-lahou
# Processing Record 48 of Set 13 | matagami
# Processing Record 49 of Set 13 | safranbolu
# Processing Record 50 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 1 of Set 14 | alberdi
# Processing Record 2 of Set 14 | middle island
# Processing Record 3 of Set 14 | witney
# Processing Record 4 of Set 14 | zhanakorgan
# Processing Record 5 of Set 14 | qinhuangdao
# Processing Record 6 of Set 14 | luganville
# Processing Record 7 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 14 | dharapuram
# Processing Record 9 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 14 | luga
# Processing Record 11 of Set 14 | kropotkin
# Processing Record 12 of Set 14 | letnik
# Processing Record 13 of Set 14 | non sang
# Processing Record 14 of Set 14 | yumen
# Processing Record 15 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 14 | beppu
# Processing Record 17 of Set 14 | tabuk
# Processing Record 18 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | ati
# Processing Record 20 of Set 14 | hirara
# Processing Record 21 of Set 14 | kiama
# Processing Record 22 of Set 14 | minnedosa
# Processing Record 23 of Set 14 | marawi
# Processing Record 24 of Set 14 | muswellbrook
# Processing Record 25 of Set 14 | chara
# Processing Record 26 of Set 14 | kokopo
# Processing Record 27 of Set 14 | zabol
# Processing Record 28 of Set 14 | iguape
# Processing Record 29 of Set 14 | warrnambool
# Processing Record 30 of Set 14 | lidkoping
# Processing Record 31 of Set 14 | san jeronimo
# Processing Record 32 of Set 14 | maceio
# Processing Record 33 of Set 14 | kapit
# Processing Record 34 of Set 14 | curuca
# Processing Record 35 of Set 14 | nishihara
# Processing Record 36 of Set 14 | shaunavon
# Processing Record 37 of Set 14 | kutum
# Processing Record 38 of Set 14 | veraval
# Processing Record 39 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 14 | nassau
# Processing Record 41 of Set 14 | yukhnov
# Processing Record 42 of Set 14 | mongoumba
# Processing Record 43 of Set 14 | lagoa
# Processing Record 44 of Set 14 | mankapur
# Processing Record 45 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 14 | maunabo
# Processing Record 48 of Set 14 | hayrabolu
# Processing Record 49 of Set 14 | bouca
# Processing Record 50 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 15 | shizukuishi
# Processing Record 2 of Set 15 | teya
# Processing Record 3 of Set 15 | port augusta
# Processing Record 4 of Set 15 | akranes
# Processing Record 5 of Set 15 | jubayl
# City not found. Skipping...
# Processing Record 6 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 7 of Set 15 | honningsvag
# Processing Record 8 of Set 15 | gordeyevka
# Processing Record 9 of Set 15 | husavik
# Processing Record 10 of Set 15 | kollo
# Processing Record 11 of Set 15 | fukue
# Processing Record 12 of Set 15 | korla
# Processing Record 13 of Set 15 | kerman
# Processing Record 14 of Set 15 | paralion astros
# City not found. Skipping...
# Processing Record 15 of Set 15 | whitehorse
# Processing Record 16 of Set 15 | boysun
# Processing Record 17 of Set 15 | bonthe
# Processing Record 18 of Set 15 | la baneza
# Processing Record 19 of Set 15 | kerema
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | palu
# Processing Record 22 of Set 15 | dakar
# Processing Record 23 of Set 15 | san cristobal
# Processing Record 24 of Set 15 | tucurui
# Processing Record 25 of Set 15 | tolaga bay
# Processing Record 26 of Set 15 | syracuse
# Processing Record 27 of Set 15 | san ramon
# Processing Record 28 of Set 15 | uk
# City not found. Skipping...
# Processing Record 29 of Set 15 | nouadhibou
# Processing Record 30 of Set 15 | hualmay
# Processing Record 31 of Set 15 | indiaroba
# Processing Record 32 of Set 15 | saint anthony
# Processing Record 33 of Set 15 | mmabatho
# Processing Record 34 of Set 15 | mildura
# Processing Record 35 of Set 15 | kankaanpaa
# Processing Record 36 of Set 15 | rio gallegos
# Processing Record 37 of Set 15 | angra
# City not found. Skipping...
# Processing Record 38 of Set 15 | najran
# Processing Record 39 of Set 15 | luba
# Processing Record 40 of Set 15 | kathmandu
# Processing Record 41 of Set 15 | zyryanka
# Processing Record 42 of Set 15 | pingzhuang
# Processing Record 43 of Set 15 | atambua
# Processing Record 44 of Set 15 | statesboro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Victoria  22.29  114.16     79.00        88         100        8.99
# 1     Mahebourg -20.41   57.70     69.80        68          75       12.75
# 2    Walvis Bay -22.96   14.51     73.40        16           0       11.41
# 3       Bubaque  11.28  -15.83     80.98        84          99       11.63
# 4   Paragominas  -2.97  -47.48     82.40        56          76        2.82
# 5  Ponta Do Sol  32.67  -17.10     71.60        68          20       17.22
# 6         Vaini -21.20 -175.20     73.40        88          75       10.29
# 7    Georgetown   5.41  100.34     82.40        78          20        5.82
# 8         Gombe  10.29   11.17     73.11        91          99        7.58
# 9        Hobart -42.88  147.33     46.40        65          75        8.05
#
#   Country Current Description                 Date
# 0      HK          light rain  2020-08-02 22:00:08
# 1      MU       broken clouds  2020-08-02 22:03:47
# 2      NA           clear sky  2020-08-02 21:53:55
# 3      GW     overcast clouds  2020-08-02 22:03:47
# 4      BR       broken clouds  2020-08-02 22:01:07
# 5      PT          few clouds  2020-08-02 22:03:47
# 6      TO       broken clouds  2020-08-02 22:03:48
# 7      MY          few clouds  2020-08-02 22:01:45
# 8      NG     overcast clouds  2020-08-02 22:03:48
# 9      AU          light rain  2020-08-02 22:03:48

# %%
new_coloum_order =["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_coloum_order]
city_data_df.head()
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0     Victoria      HK  2020-08-02 22:00:08  22.29  114.16     79.00
# 1    Mahebourg      MU  2020-08-02 22:03:47 -20.41   57.70     69.80
# 2   Walvis Bay      NA  2020-08-02 21:53:55 -22.96   14.51     73.40
# 3      Bubaque      GW  2020-08-02 22:03:47  11.28  -15.83     80.98
# 4  Paragominas      BR  2020-08-02 22:01:07  -2.97  -47.48     82.40
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        88         100        8.99          light rain
# 1        68          75       12.75       broken clouds
# 2        16           0       11.41           clear sky
# 3        84          99       11.63     overcast clouds
# 4        56          76        2.82       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
